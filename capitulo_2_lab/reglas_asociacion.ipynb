# %%
from pycaret.datasets import get_data
data = get_data('france')
# Out:
#   InvoiceNo StockCode                      Description  Quantity  \
# 0    536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 1    536370     22727        ALARM CLOCK BAKELIKE RED         24
# 2    536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 3    536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 4    536370     21883                 STARS GIFT TAPE         24
#
#       InvoiceDate  UnitPrice  CustomerID Country
# 0  12/1/2010 8:45       3.75     12583.0  France
# 1  12/1/2010 8:45       3.75     12583.0  France
# 2  12/1/2010 8:45       3.75     12583.0  France
# 3  12/1/2010 8:45       0.85     12583.0  France
# 4  12/1/2010 8:45       0.65     12583.0  France

# %%
from pycaret.arules import *
s = setup(data = data, transaction_id = 'InvoiceNo', item_id = 'Description', ignore_items = ['POSTAGE'])
# Out:
# <style type="text/css">
# </style>
# <table id="T_0efd2">
#   <thead>
#     <tr>
#       <th id="T_0efd2_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_0efd2_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0efd2_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_0efd2_row0_col1" class="data row0 col1" >3671</td>
#     </tr>
#     <tr>
#       <td id="T_0efd2_row1_col0" class="data row1 col0" ># Transactions</td>
#       <td id="T_0efd2_row1_col1" class="data row1 col1" >461</td>
#     </tr>
#     <tr>
#       <td id="T_0efd2_row2_col0" class="data row2 col0" ># Items</td>
#       <td id="T_0efd2_row2_col1" class="data row2 col1" >1565</td>
#     </tr>
#     <tr>
#       <td id="T_0efd2_row3_col0" class="data row3 col0" >Ignore Items</td>
#       <td id="T_0efd2_row3_col1" class="data row3 col1" >['POSTAGE']</td>
#     </tr>
#   </tbody>
# </table>

# %%
arules = create_model(metric='confidence', threshold=0.5, min_support=0.085)
arules
# Out:
# /Users/emilio/opt/anaconda3/lib/python3.9/site-packages/mlxtend/frequent_patterns/fpcommon.py:111: DeprecationWarning:
#
# DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#                              antecedents  \
# 0        (SET/6 RED SPOTTY PAPER PLATES)
# 1          (SET/6 RED SPOTTY PAPER CUPS)
# 2        (SET/6 RED SPOTTY PAPER PLATES)
# 3  (SET/20 RED RETROSPOT PAPER NAPKINS )
# 4  (SET/20 RED RETROSPOT PAPER NAPKINS )
# 5             (PLASTERS IN TIN SPACEBOY)
# 6          (SET/6 RED SPOTTY PAPER CUPS)
# 7     (PLASTERS IN TIN WOODLAND ANIMALS)
# 8     (PLASTERS IN TIN WOODLAND ANIMALS)
# 9       (PLASTERS IN TIN CIRCUS PARADE )
#
#                              consequents  antecedent support  \
# 0          (SET/6 RED SPOTTY PAPER CUPS)              0.1085
# 1        (SET/6 RED SPOTTY PAPER PLATES)              0.1171
# ...

# %%
arules.to_excel('reglas.xlsx')
